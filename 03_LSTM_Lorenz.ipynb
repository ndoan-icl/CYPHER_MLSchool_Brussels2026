# %% [markdown]
# # LSTM to learn the dynamics of the Lorenz system
# ### Author: N. A. K. Doan (n.doan@imperial.ac.uk)
# In this session, we will use what you learned about recurrent neural network to design a neural network that can learn the dynamics of a chaotic system (derived from atmospheric flow) called the Lorenz system.
#
# The equations of the Lorenz system are given by:
#     \begin{equation}
#     \frac{dx}{dt} = \sigma (y-x), \hspace{11pt} \frac{dy}{dt} = x(\rho-z) - y, \hspace{11pt}, \frac{dz}{dt}=xy-\beta z
#     \end{equation}
#
# Typical values for the parameters are $\sigma=10$ and $\beta = 8/3$.

# %%
use_colab = False
if use_colab:
    # !git clone -b main https://github.com/ndoan-icl/CYPHER_MLSchool_Brussels2026.git

    # from google.colab import drive
    # drive.mount('/content/drive')

# %% [markdown]
# # 1 Loading librairies

# %%
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D
import numpy as np
import tensorflow as tf
# Out:
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# I0000 00:00:1788953420.129520   70806 port.cc:153] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# I0000 00:00:1788953420.130000   70806 cudart_stub.cc:31] Could not find cuda drivers on your machine, GPU will not be used.
# I0000 00:00:1788953420.176797   70806 cpu_feature_guard.cc:227] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX_VNNI AVX_VNNI_INT8 AVX_NE_CONVERT FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# I0000 00:00:1788953421.867340   70806 port.cc:153] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# I0000 00:00:1788953421.867733   70806 cudart_stub.cc:31] Could not find cuda drivers on your machine, GPU will not be used.

# %% [markdown]
# # 2 Load dataset

# %%
if use_colab:
    fld = './CYPHER_MLSchool_Brussels2026/'
else:
    fld = './'
np_file = np.load( fld + 'Lorenz_data/LorenzSys_Lorenz_data.npz')
X = np_file['X'] # Data
dt = np_file['dt']
t_split = np_file['t_stop_train']
t_skip = np_file['t_skip']
val_ratio = np_file['val_ratio']
Lyap = np_file['Lyap']

# remove the transient from the dataset
i_skip = int(t_skip/dt)
X = X[i_skip:,:]

# %%
# %matplotlib inline
fig = plt.figure()
ax = fig.add_subplot(111,projection='3d')
ax.plot(X[:,0],X[:,1],X[:,2])

# %%
plt.figure()
plt.plot(X[0:1000,0])
plt.plot(X[0:1000,1])
plt.plot(X[0:1000,2])

# %% [markdown]
# # 3 Dataset preparation
# We now need to define the problem that we try to solve, meaning what is the purpose of our neural network.
#
# Here we will try to develop the neural network so that it can reproduce autonomously the dynamics of the Lorenz system. That means that the input of the neural network will be the $N_{step}$ states in the past, $[\underline{x}(t-N_{step}),...,\underline{x}(t-1)]$, and it has to predict the next state at time $t$, $\underline{x}(t)$.
#
# This allows us to define our training dataset.

# %%
# Dataset normalization
Xmean = np.mean(X,0)
Xstd = np.std(X,0)
X = X - np.mean(X,0)
X = X/np.std(X,0)

# %%
# we define the input/output split
input_all = X[:-1,:]
output_all = X[1:,:]

# we further split the entire dataset into
# training/validation/test dataset
val_ratio = 0.75
test_ratio = 0.9
idx_val = int(np.round(val_ratio*len(input_all)))
idx_test = int(np.round(test_ratio*len(input_all)))

input_train = input_all[:idx_val,:]
output_train = output_all[:idx_val,:]

input_val = input_all[idx_val:idx_test,:]
output_val = output_all[idx_val:idx_test,:]

input_test = input_all[idx_test:,:]
output_test = output_all[idx_test:,:]

# %% [markdown]
# We now need to further reorganize the dataset so that for an input composed of $N_{step}$ timesteps, corresponds the output at time $t$.

# %%
Nstep = 10

#reshape the data
inn = []
for i in range(input_train.shape[0]-Nstep):
    inn.append(input_train[i:i+Nstep,:])
input_train = np.array(inn)
output_train = output_train[Nstep-1:-1,:]

inn = []
for i in range(input_val.shape[0]-Nstep):
    inn.append(input_val[i:i+Nstep,:])
input_val = np.array(inn)
output_val = output_val[Nstep-1:-1,:]

# %%
print(output_train.shape)
# Out:
# (84365, 3)

# %% [markdown]
# # 4. Definition of our neural network
# We now define our neural network

# %%
model = tf.keras.Sequential()
model.add(tf.keras.layers.LSTM(10,input_shape=(Nstep,3),return_sequences=True))
model.add(tf.keras.layers.LSTM(5))
model.add(tf.keras.layers.Dense(3,activation='linear'))

model.compile(optimizer='adam',loss='mse')

model.summary()
# Out:
# Model: "sequential_2"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ lstm_2 (LSTM)                   │ (None, 10, 10)         │           560 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_2 (Dense)                 │ (None, 10, 3)          │            33 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 593 (2.32 KB)
#  Trainable params: 593 (2.32 KB)
#  Non-trainable params: 0 (0.00 B)

# %% [markdown]
# # 5. Training of the neural network

# %%
checkpoint_filepath = fld + './checkpoint_LSTM_Lorenz.weights.h5'
model_checkpoint_callback = tf.keras.callbacks.ModelCheckpoint(
    filepath=checkpoint_filepath,
    save_weights_only=True,
    monitor='val_loss',
    mode='min',
    save_best_only=True)
early_stop_callback = tf.keras.callbacks.EarlyStopping(monitor='val_loss', patience=3)

# %%
nb_epochs = 10

history = model.fit(input_train, output_train, validation_data=(input_val, output_val),
                    epochs=nb_epochs, verbose=1, callbacks=[model_checkpoint_callback,early_stop_callback])

model.load_weights(checkpoint_filepath)
# Out:
# Epoch 1/10
# ---------------------------------------------------------------------------
# InvalidArgumentError                      Traceback (most recent call last)
# Cell In[18], line 3
#       1 nb_epochs = 10
# ----> 3 history = model.fit(input_train, output_train, validation_data=(input_val, output_val),
#       4                     epochs=nb_epochs, verbose=1, callbacks=[model_checkpoint_callback,early_stop_callback])
#       6 model.load_weights(checkpoint_filepath)
#
# File ~/miniconda3/envs/cypher/lib/python3.10/site-packages/keras/src/utils/traceback_utils.py:122, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#     119     filtered_tb = _process_traceback_frames(e.__traceback__)
#     120     # To get the full stack trace, call:
#     121     # `keras.config.disable_traceback_filtering()`
# --> 122     raise e.with_traceback(filtered_tb) from None
#     123 finally:
#     124     del filtered_tb
#
# File ~/miniconda3/envs/cypher/lib/python3.10/site-packages/tensorflow/python/eager/execute.py:53, in quick_execute(op_name, num_outputs, inputs, attrs, ctx, name)
#      51 try:
#      52   ctx.ensure_initialized()
# ---> 53   tensors = pywrap_tfe.TFE_Py_Execute(ctx._handle, device_name, op_name,
#      54                                       inputs, attrs, num_outputs)
#      55 except core._NotOkStatusException as e:
#      56   if name is not None:
#
# InvalidArgumentError: Graph execution error:
#
# Detected at node gradient_tape/compile_loss/mse/sub/BroadcastGradientArgs defined at (most recent call last):
#   File "/home/ndoan/miniconda3/envs/cypher/lib/python3.10/runpy.py", line 196, in _run_module_as_main
#
#   File "/home/ndoan/miniconda3/envs/cypher/lib/python3.10/runpy.py", line 86, in _run_code
#
#   File "/home/ndoan/miniconda3/envs/cypher/lib/python3.10/site-packages/ipykernel_launcher.py", line 18, in <module>
#
#   File "/home/ndoan/miniconda3/envs/cypher/lib/python3.10/site-packages/traitlets/config/application.py", line 1080, in launch_instance
#
#   File "/home/ndoan/miniconda3/envs/cypher/lib/python3.10/site-packages/ipykernel/kernelapp.py", line 807, in start
#
#   File "/home/ndoan/miniconda3/envs/cypher/lib/python3.10/site-packages/tornado/platform/asyncio.py", line 211, in start
#
#   File "/home/ndoan/miniconda3/envs/cypher/lib/python3.10/asyncio/base_events.py", line 603, in run_forever
#
#   File "/home/ndoan/miniconda3/envs/cypher/lib/python3.10/asyncio/base_events.py", line 1909, in _run_once
#
#   File "/home/ndoan/miniconda3/envs/cypher/lib/python3.10/asyncio/events.py", line 80, in _run
#
#   File "/home/ndoan/miniconda3/envs/cypher/lib/python3.10/site-packages/ipykernel/utils.py", line 71, in preserve_context
#
#   File "/home/ndoan/miniconda3/envs/cypher/lib/python3.10/site-packages/ipykernel/kernelbase.py", line 621, in shell_main
#
#   File "/home/ndoan/miniconda3/envs/cypher/lib/python3.10/site-packages/ipykernel/kernelbase.py", line 478, in dispatch_shell
#
#   File "/home/ndoan/miniconda3/envs/cypher/lib/python3.10/site-packages/ipykernel/ipkernel.py", line 372, in execute_request
#
#   File "/home/ndoan/miniconda3/envs/cypher/lib/python3.10/site-packages/ipykernel/kernelbase.py", line 834, in execute_request
#
#   File "/home/ndoan/miniconda3/envs/cypher/lib/python3.10/site-packages/ipykernel/ipkernel.py", line 460, in do_execute
#
#   File "/home/ndoan/miniconda3/envs/cypher/lib/python3.10/site-packages/ipykernel/zmqshell.py", line 665, in run_cell
#
#   File "/home/ndoan/miniconda3/envs/cypher/lib/python3.10/site-packages/IPython/core/interactiveshell.py", line 3077, in run_cell
#
#   File "/home/ndoan/miniconda3/envs/cypher/lib/python3.10/site-packages/IPython/core/interactiveshell.py", line 3132, in _run_cell
#
#   File "/home/ndoan/miniconda3/envs/cypher/lib/python3.10/site-packages/IPython/core/async_helpers.py", line 128, in _pseudo_sync_runner
#
#   File "/home/ndoan/miniconda3/envs/cypher/lib/python3.10/site-packages/IPython/core/interactiveshell.py", line 3336, in run_cell_async
#
#   File "/home/ndoan/miniconda3/envs/cypher/lib/python3.10/site-packages/IPython/core/interactiveshell.py", line 3519, in run_ast_nodes
#
#   File "/home/ndoan/miniconda3/envs/cypher/lib/python3.10/site-packages/IPython/core/interactiveshell.py", line 3579, in run_code
#
#   File "/tmp/ipykernel_70806/4144021361.py", line 3, in <module>
#
#   File "/home/ndoan/miniconda3/envs/cypher/lib/python3.10/site-packages/keras/src/utils/traceback_utils.py", line 117, in error_handler
#
#   File "/home/ndoan/miniconda3/envs/cypher/lib/python3.10/site-packages/keras/src/backend/tensorflow/trainer.py", line 399, in fit
#
#   File "/home/ndoan/miniconda3/envs/cypher/lib/python3.10/site-packages/keras/src/backend/tensorflow/trainer.py", line 241, in function
#
#   File "/home/ndoan/miniconda3/envs/cypher/lib/python3.10/site-packages/keras/src/backend/tensorflow/trainer.py", line 154, in multi_step_on_iterator
#
#   File "/home/ndoan/miniconda3/envs/cypher/lib/python3.10/site-packages/keras/src/backend/tensorflow/trainer.py", line 125, in wrapper
#
#   File "/home/ndoan/miniconda3/envs/cypher/lib/python3.10/site-packages/keras/src/backend/tensorflow/trainer.py", line 134, in one_step_on_data
#
#   File "/home/ndoan/miniconda3/envs/cypher/lib/python3.10/site-packages/keras/src/backend/tensorflow/trainer.py", line 81, in train_step
#
# Incompatible shapes: [32,3] vs. [32,10,3]
# 	 [[{{node gradient_tape/compile_loss/mse/sub/BroadcastGradientArgs}}]] [Op:__inference_multi_step_on_iterator_4322]

# %% [markdown]
# # 6. Visualization of the prediction from the neural network

# %%
x_ref = X[idx_test:,:]
print(x_ref.shape)
x_ref = x_ref[:1000,:]

# %%
# We look at the natural response of the neural network
Y = []
y_last = x_ref[0:Nstep, :].reshape((1, Nstep, 3))
print('start natural response')
for i in range(x_ref.shape[0] - Nstep):
    Y.append(model.predict(y_last, verbose=0))
    y_last = np.append(y_last, Y[i].reshape(1, 1, 3), axis=1)
    y_last = y_last[:, 1:, :]
    if (i%50==0):
        print('%d prediction done' % (i + 1))

# %%
Y = np.array(Y)
print(Y.shape)
Y = Y.reshape(Y.shape[0], Y.shape[2])
Y = np.vstack((x_ref[:Nstep, :], Y))

# %%
# calculate Error
err = np.log(np.linalg.norm(Y[Nstep:, :] - x_ref[Nstep:, :], axis=1)) / np.sqrt(
    np.average(np.square(np.linalg.norm(x_ref[Nstep:, :], axis=1))))

tlin = np.arange(len(err))*dt
# %matplotlib inline
fig = plt.figure()
ax1 = fig.add_subplot(221)
ax1.plot(tlin,err)

ax2 = fig.add_subplot(222)
ax2.plot(tlin,x_ref[Nstep:, 0])
ax2.plot(tlin,Y[Nstep:, 0], '--')

ax3 = fig.add_subplot(223)
ax3.plot(tlin,x_ref[Nstep:, 1])
ax3.plot(tlin,Y[Nstep:, 1], '--')

ax4 = fig.add_subplot(224)
ax4.plot(tlin,x_ref[Nstep:, 2])
ax4.plot(tlin,Y[Nstep:, 2], '--')

fig2 = plt.figure()
ax3d = fig2.add_subplot(111,projection='3d')
ax3d.plot(x_ref[Nstep:,0],x_ref[Nstep:,1],x_ref[Nstep:,2])
ax3d.plot(Y[Nstep:,0],Y[Nstep:,1],Y[Nstep:,2],'r')

# %% [markdown]
# We can also analyse the prediction from the network by comparing the statistics (probability density function) of the different components of the prediction and compare them to the true statistics.

# %%
for i in range(3):
    plt.subplot(1,3,i+1)
    xmin = np.min(x_ref[Nstep:,i])
    xmax = np.max(x_ref[Nstep:,i])
    xrange = np.linspace(xmin,xmax,20)
    hist_ref, bin_edges = np.histogram(X[:,i], xrange,density=True)
    hist_NN, bin_edges = np.histogram(Y[Nstep:,i], xrange,density=True)
    plt.plot(xrange[1:],hist_ref)
    plt.plot(xrange[1:],hist_NN)
    plt.xlabel(f'$\phi_{i+1}$')
    plt.legend(['Reference', 'NN'])
plt.show()
